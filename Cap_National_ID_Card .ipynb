# %%
# !apt-get install -y tesseract-ocr
# !pip install pytesseract
# !apt-get install -y tesseract-ocr-eng
# !apt-get install -y tesseract-ocr-ara  
# !apt-get install -y tesseract-ocr-hin  
# !pip install pytesseract opencv-python-headless pandas
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\hp\anaconda3\lib\site-packages)
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# ...

# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import pytesseract
import os


pytesseract.pytesseract.tesseract_cmd = r'D:/Tesseract-OCR/tesseract.exe'

# %%
img_path = 'D:/quetions/archive/image1.jpeg'
img = cv2.imread(img_path)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
plt.imshow(blurred,cmap='gray');

# %%
original=cv2.imread('D:/quetions/archive/image1.jpeg')
original=cv2.cvtColor(original,cv2.COLOR_BGR2RGB)
plt.imshow(original)

# %%
img=cv2.imread('D:/quetions/archive/image1.jpeg',0)
plt.imshow(img)

# %%
print(pytesseract.image_to_string(original, lang='ara'))
# Out:
# ذكر
# البطاقة سارية:
#
# 35و
#
# 0
# رك
# حش 1
#
# ذال لقم
#
# ا ا رو
#
# ؟
#
# ؟.١‎ 1١

# %%
print(pytesseract.image_to_string(img, lang='ara'))
# Out:
# البطاقة سارية حت 1 2ق
#
# نجا
#
# بحب ب ص ولع او كي؟
#
# ار موبيليا
#
# 7
#
# 0

# %%
ret,th=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(th)

# %%
print(pytesseract.image_to_string(th, lang='ara'))
# Out:
# ال ا ل ل ل الل كن 86
#
# نجار موبيليا
#
# 5 وت اا
#
# ذكر مسلم متزوج
#
# 55
# 8
#
# ا
#
# 3
#
# 1
# 0 0
# 0 1
#
# 0
#
# ين سشننها
#
# لمتاوييعم
#
# كم
#
# 0 حالم 2

# %%
ret,th2=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
plt.imshow(th2)

# %%
print(pytesseract.image_to_string(th2, lang='ara'))
# Out:
# ال ا ل ل ل الل كن 8
#
# نجار موبيليا
#
# 5 وت اا
#
# ذكر مسلم متزوج
#
# 55
# 8
#
# ا
#
# 3
#
# 1
# 0 0
# 0 1
#
# 0
#
# ين سشننها
#
# لمتاويع
#
# كم
#
# ا حالم 0

# %%
ret, thresh= cv2.threshold(img, 127, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)  
plt.imshow(thresh)     
print(pytesseract.image_to_string(thresh, lang='ara'))
# Out:
# البطاقة سارية حش "11 القل؟”
#
# نجا
#
# ا ا ل ان
#
# ار موبيليا
#
# 5
#
# ا"

# %%
thresh1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 199,49) 
plt.imshow(thresh1)     
print(pytesseract.image_to_string(thresh1, lang='ara'))
# Out:
# لل ل لشف
#
# ا
# 0

# %%
img2=cv2.imread('D:/quetions/archive/image2.jpeg',0)
plt.imshow(img2)

# %%
thresh2 = cv2.adaptiveThreshold(img2, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY, 199,45) 
plt.imshow(thresh2)

# %%
thresh1= cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY, 199,45) 
plt.imshow(thresh1)

# %%
from pytesseract import Output

d = pytesseract.image_to_data(original, output_type=Output.DICT)
n_boxes = len(d['level'])
for i in range(n_boxes):
    (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

plt.imshow(img)

# %%
img_path = 'D:/quetions/archive/image2.jpeg'
img = cv2.imread(img_path)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
plt.imshow(blurred,cmap='gray');

# %%
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
edged = cv2.Canny(blurred, 30, 150)
contours, _ = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)

# %%
img = cv2.imread(img_path,1)
img = cv2.resize(img,(750,500))
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
# blurred = cv2.GaussianBlur(blurred, (3, 3), 0)

gaussian = cv2.adaptiveThreshold(blurred,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,91,41)

edged = cv2.Canny(gray, 100, 150)
plt.figure(figsize=(20,12))
plt.subplot(131),plt.imshow(gaussian,cmap='gray'),plt.title('Gaussian')
plt.subplot(132),plt.imshow(blurred,cmap='gray'),plt.title('blurred')
plt.subplot(133),plt.imshow(edged,cmap='gray'),plt.title('edged')
plt.show()

# %%
print(pytesseract.image_to_string(gaussian,lang='ara'))
# Out:
# 1 1 00 0
# ‎١‏ |
# هانى
# صابر مشرف مكاوى ,
# مساكن أطلس -عمنية . .* ١ب‏ 9م١1‏ 37 1(
#
# اول السلام - القاهره
#
# اد ا لي يال الملذيا
# 707 ]8

# %%
image = cv2.imread(img_path,1)
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
gaussian = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,91,41)
_, binary_image = cv2.threshold(gaussian, 0, 10, cv2.THRESH_BINARY)

# %%
plt.imshow(binary_image,cmap='gray')

# %%
print(pytesseract.image_to_string(binary_image,lang='ara'))
# Out:
# هانى
#
# صابر مشرف مكاوى
#
# مساكن أطلس -عمنيةٌ ‎٠‏ .٠؟١-ب07"-م١‏
# اول السلاو - الشقاعره
#
# لا/ا1ا1". ‎.١‏ *؟ ‎١5‏ ثم"
#
# . 0700107م6ع

# %%
img = cv2.resize(image,(400,650))
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
# Apply noise reduction (e.g., Gaussian blur)
gaussian = cv2.adaptiveThreshold(blurred,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,91,41)

# Apply thresholding to make text more prominent
_, binary_image = cv2.threshold(gaussian, 0, 10, cv2.THRESH_BINARY)
plt.imshow(binary_image,cmap='gray')
print(pytesseract.image_to_string(binary_image,lang='ara'))
# Out:
# صابر مشرف مكاوى
#
# مساكن أطلس -عمنية . ‎٠‏ ١-ب07"-م١‏
#
# اول السلام - القاهره
#
# /ا/1ا1”.
#
# "م١‎ 1١5 5: ‏؟.‎
#
# جع
# 1#
#
# 3
#
# 7م

# %%
plt.imshow(img[int(img.shape[0]*0.3) : int(img.shape[0]*0.5)])

# %%
plt.imshow(binary_image[int(img.shape[0]*0.3) : int(img.shape[0]*0.45)])

# %%
print(pytesseract.image_to_string(binary_image[int(img.shape[0]*0.3) : int(img.shape[0]*0.5)],lang='ara'))
# Out:
# ْ 1 و#ك
# صابر

# %%
plt.imshow(binary_image[int(img.shape[0]*0.45) : int(img.shape[0]*0.7)])

# %%
print(pytesseract.image_to_string(img[int(img.shape[0]*0.45) : int(img.shape[0]*0.7)],lang='ara'))
# Out:
# سال اللي تلا. ,باكرا | |
# ول امار التآلرة

# %%
plt.imshow(binary_image[int(img.shape[0]*0.7) : int(img.shape[0]*0.8)])

# %%
pytesseract.image_to_string(binary_image[int(img.shape[0]*0.45) : int(img.shape[0]*0.7)], lang='ara').strip().replace('\n',' ')
pytesseract.image_to_string(binary_image[int(img.shape[0]*0.45) : int(img.shape[0]*0.7)], lang='ara').strip().replace('\n',' ')
# Out:
# 'مساكن أطلس -عمنية . \u200e٠\u200f ١-ب07"-م١\u200f اول السلام - القاهره'
